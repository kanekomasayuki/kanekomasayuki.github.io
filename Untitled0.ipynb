# %%
# google　driveをGoogle Colaboraroryからアクセスできる場所にマウントする
from google.colab import drive
drive.mount('/content/drive')
# Google Colaborarory環境にはtreeが入っていないので入れる
# !sudo apt-get install tree
# /path/to/dirはtreeを発行したいディレクトリに変更
# %cd drive/MyDrive/path/to/dir

# !tree -N
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# │       │           │   │   └── syogaikoku
# │       │           │   │       ├── css
# │       │           │   │       │   ├── common.css
# │       │           │   │       │   ├── reset.css
# │       │           │   │       │   └── style.css
# │       │           │   │       ├── images
# │       │           │   │       │   ├── 1023.png
# │       │           │   │       │   ├── back_sp01.jpg
# │       │           │   │       │   ├── copyright.png
# │       │           │   │       │   ├── countries-back_pc.jpg
# │       │           │   │       │   ├── eleku01.png
# │       │           │   │       │   ├── eleku04.png
# │       │           │   │       │   ├── eleku07.png
# │       │           │   │       │   ├── eleku-onkaron01 2.png
# │       │           │   │       │   ├── erec01_pc.png
# │       │           │   │       │   ├── erec_01sp.png
# │       │           │   │       │   ├── erec_02sp.png
# │       │           │   │       │   ├── finland.png
# │       │           │   │       │   ├── mauntain_pc01.png
# │       │           │   │       │   ├── onkaron01.png
# │       │           │   │       │   ├── onkaron02.png
# │       │           │   │       │   ├── onkaron03.png
# │       │           │   │       │   ├── onkaron04.png
# │       │           │   │       │   ├── snow.png
# │       │           │   │       │   ├── step-pc.png
# │       │           │   │       │   ├── step-sp.png
# │       │           │   │       │   ├── strata.jpg
# │       │           │   │       │   ├── strata_syogaikoku.jpg
# │       │           │   │       │   ├── swiss.png
# │       │           │   │       │   ├── syogaikoku_back01pc.jpg
# │       │           │   │       │   ├── syogaikoku_back022.jpg
# │       │           │   │       │   ├── syogaikoku_back02pc.jpg
# │       │           │   │       │   ├── syogaikoku_back03pc.jpg
# │       │           │   │       │   ├── syogaikoku_back04pc.jpg
# │       │           │   │       │   ├── syogaikoku_back06pc.jpg
# │       │           │   │       │   ├── syogaikoku_backe05pc.jpg
# │       │           │   │       │   ├── syogaikoku_backe07pc.jpg
# │       │           │   │       │   ├── syogaikoku-sp02.jpg
# │       │           │   │       │   ├── syogaikoku_sp04.jpg
# │       │           │   │       │   ├── syogaikoku_sp05.jpg
# │       │           │   │       │   ├── syogaikoku_sp06.jpg
# │       │           │   │       │   ├── syogaikoku_step01_pc.png
# │       │           │   │       │   ├── syogaikoku_strata-sp.jpg
# │       │           │   │       │   └── test.jpg
# │       │           │   │       ├── img
# │       │           │   │       │   ├── elec06.png
# │       │           │   │       │   ├── eleku02.png
# │       │           │   │       │   ├── eleku05.png
# │       │           │   │       │   ├── eleku06.png
# │       │           │   │       │   ├── haikei02.jpg
# │       │           │   │       │   ├── haikei03.jpg
# │       │           │   │       │   ├── jinkou.png
# │       │           │   │       │   ├── kirakira01.png
# │       │           │   │       │   ├── kirakira01_SP.png
# │       │           │   │       │   ├── kirakira02.png
# │       │           │   │       │   ├── kirakira02_SP.png
# │       │           │   │       │   ├── main_img.jpg
# │       │           │   │       │   ├── main_img_SP.jpg
# │       │           │   │       │   ├── saigai.png
# │       │           │   │       │   ├── shisetsu.png
# │       │           │   │       │   └── tennen.png
# │       │           │   │       ├── index.gdoc
# │       │           │   │       └── js
# │       │           │   │           ├── jquery-1.11.3.min.js
# │       │           │   │           ├── script.js
# │       │           │   │           └── snowfall.jquery.js
# │       │           │   ├── w_sendai_kawamura
# │       │           │   │   ├── css
# │       │           │   │   │   ├── story
# │       │           │   │   │   │   └── style.css
# │       │           │   │   │   └── top
# │       │           │   │   │       └── style.css
# │       │           │   │   ├── img
# │       │           │   │   │   ├── header
# │       │           │   │   │   │   ├── electric.png
# │       │           │   │   │   │   ├── fb.png
# │       │           │   │   │   │   ├── header_callout.svg
# │       │           │   │   │   │   ├── inst.png
# │       │           │   │   │   │   ├── mole_callout.svg
# │       │           │   │   │   │   ├── mole.svg
# │       │           │   │   │   │   ├── sub_ttl.svg
# │       │           │   │   │   │   └── ytb.png
# │       │           │   │   │   ├── story
# │       │           │   │   │   │   ├── character
# │       │           │   │   │   │   │   ├── story1_1_1.svg
# │       │           │   │   │   │   │   ├── story1_1_2.svg
# │       │           │   │   │   │   │   ├── story1_1_3.svg
# │       │           │   │   │   │   │   ├── story1_2_1.svg
# │       │           │   │   │   │   │   ├── story1_2_2.svg
# │       │           │   │   │   │   │   ├── story1_2_3.svg
# │       │           │   │   │   │   │   ├── story1_3_1.svg
# │       │           │   │   │   │   │   ├── story1_3_2.svg
# │       │           │   │   │   │   │   ├── story1_3_3.svg
# │       │           │   │   │   │   │   ├── story1_3_4.svg
# │       │           │   │   │   │   │   ├── story1_3_5.svg
# │       │           │   │   │   │   │   ├── story2_1_1.svg
# │       │           │   │   │   │   │   ├── story2_1_2.svg
# │       │           │   │   │   │   │   ├── story2_1_3.svg
# │       │           │   │   │   │   │   ├── story2_1_4.svg
# │       │           │   │   │   │   │   ├── story2_2_1.svg
# │       │           │   │   │   │   │   ├── story2_2_2.svg
# │       │           │   │   │   │   │   ├── story2_2_3.svg
# │       │           │   │   │   │   │   ├── story2_3_1.svg
# │       │           │   │   │   │   │   ├── story2_3_2.svg
# │       │           │   │   │   │   │   ├── story2_3_3.svg
# │       │           │   │   │   │   │   ├── story2_4_1.svg
# │       │           │   │   │   │   │   ├── story2_4_2.svg
# │       │           │   │   │   │   │   ├── story2_4_3.svg
# │       │           │   │   │   │   │   ├── story3_1_1.svg
# │       │           │   │   │   │   │   ├── story3_1_2.svg
# │       │           │   │   │   │   │   ├── story3_1_3.svg
# │       │           │   │   │   │   │   ├── story3_1_4.svg
# │       │           │   │   │   │   │   ├── story3_2_1.svg
# │       │           │   │   │   │   │   ├── story3_2_2.svg
# │       │           │   │   │   │   │   ├── story3_3_1.svg
# │       │           │   │   │   │   │   ├── story3_3_2.svg
# │       │           │   │   │   │   │   ├── story3_3_3.svg
# │       │           │   │   │   │   │   ├── story3_3_4.svg
# │       │           │   │   │   │   │   ├── story3_4_1.svg
# │       │           │   │   │   │   │   ├── story3_4_2.svg
# │       │           │   │   │   │   │   ├── story3_4_3.svg
# │       │           │   │   │   │   │   ├── story4_1_1.svg
# │       │           │   │   │   │   │   ├── story4_1_2.svg
# │       │           │   │   │   │   │   ├── story4_1_3.svg
# │       │           │   │   │   │   │   ├── story4_1_4.svg
# │       │           │   │   │   │   │   ├── story4_1_5.svg
# │       │           │   │   │   │   │   ├── story4_2_1.svg
# │       │           │   │   │   │   │   ├── story4_2_2.svg
# │       │           │   │   │   │   │   ├── story4_2_3.svg
# │       │           │   │   │   │   │   ├── story4_2_4.svg
# │       │           │   │   │   │   │   ├── story5_1_1.svg
# │       │           │   │   │   │   │   ├── story5_1_2.svg
# │       │           │   │   │   │   │   ├── story5_1_3.svg
# │       │           │   │   │   │   │   ├── story5_1_4.svg
# │       │           │   │   │   │   │   ├── story5_1_5.svg
# │       │           │   │   │   │   │   ├── story5_1_6.svg
# │       │           │   │   │   │   │   ├── story5_2_1.svg
# │       │           │   │   │   │   │   ├── story5_2_2.svg
# │       │           │   │   │   │   │   ├── story5_2_3.svg
# │       │           │   │   │   │   │   ├── story5_2_4.svg
# │       │           │   │   │   │   │   ├── story5_2_5.svg
# │       │           │   │   │   │   │   ├── story5_3_1.svg
# │       │           │   │   │   │   │   ├── story5_3_2.svg
# │       │           │   │   │   │   │   ├── story5_3_3.svg
# │       │           │   │   │   │   │   ├── story5_3_4.svg
# │       │           │   │   │   │   │   ├── story5_3_5.svg
# │       │           │   │   │   │   │   ├── story5_4_1.svg
# │       │           │   │   │   │   │   ├── story5_4_2.svg
# │       │           │   │   │   │   │   ├── story5_4_3.svg
# │       │           │   │   │   │   │   ├── story5_4_4.svg
# │       │           │   │   │   │   │   ├── story5_4_5.svg
# │       │           │   │   │   │   │   ├── story5_4_6.svg
# │       │           │   │   │   │   │   └── story5_4_7.svg
# │       │           │   │   │   │   ├── common
# │       │           │   │   │   │   │   └── arrow_gray.png
# │       │           │   │   │   │   ├── icon
# │       │           │   │   │   │   │   ├── last_fb.png
# │       │           │   │   │   │   │   ├── last_insta.png
# │       │           │   │   │   │   │   └── last_you.png
# │       │           │   │   │   │   └── intro
# │       │           │   │   │   │       ├── boy_1.svg
# │       │           │   │   │   │       └── rbb_1.svg
# │       │           │   │   │   └── top
# │       │           │   │   │       ├── arrow.png
# │       │           │   │   │       ├── btn.svg
# │       │           │   │   │       ├── top_arrow.svg
# │       │           │   │   │       └── top_ttl.svg
# │       │           │   │   ├── index.gdoc
# │       │           │   │   ├── js
# │       │           │   │   │   ├── app.js
# │       │           │   │   │   ├── jquery-3.4.1.min.js
# │       │           │   │   │   ├── jquery.mousewheel.min.js
# │       │           │   │   │   └── profaim-ruby-autoapply-mini.js
# │       │           │   │   ├── sp
# │       │           │   │   │   ├── css
# │       │           │   │   │   │   ├── reset.css
# │       │           │   │   │   │   └── style.css
# │       │           │   │   │   ├── img
# │       │           │   │   │   │   ├── arrow_gray.svg
# │       │           │   │   │   │   ├── btn.svg
# │       │           │   │   │   │   ├── last_fb.png
# │       │           │   │   │   │   ├── last_insta.png
# │       │           │   │   │   │   ├── last_you.png
# │       │           │   │   │   │   ├── sp_btn.svg
# │       │           │   │   │   │   ├── sp_intro_boy.svg
# │       │           │   │   │   │   ├── sp_intro_rbb.svg
# │       │           │   │   │   │   ├── sp_mogura.png
# │       │           │   │   │   │   ├── sp_nav_fa.png
# │       │           │   │   │   │   ├── sp_navi_li.svg
# │       │           │   │   │   │   ├── sp_nav_ins.png
# │       │           │   │   │   │   ├── sp_navi.svg
# │       │           │   │   │   │   ├── sp_nav_you.png
# │       │           │   │   │   │   ├── sp_top_tt.svg
# │       │           │   │   │   │   ├── story1_1_1.svg
# │       │           │   │   │   │   ├── story1_1_2.svg
# │       │           │   │   │   │   ├── story1_1_3.svg
# │       │           │   │   │   │   ├── story1_2_1.svg
# │       │           │   │   │   │   ├── story1_2_2.svg
# │       │           │   │   │   │   ├── story1_2_3.svg
# │       │           │   │   │   │   ├── story1_3_1.svg
# │       │           │   │   │   │   ├── story1_3_2.svg
# │       │           │   │   │   │   ├── story1_3_3.svg
# │       │           │   │   │   │   ├── story1_3_4.svg
# │       │           │   │   │   │   ├── story1_3_5.svg
# │       │           │   │   │   │   ├── story2_1_1.svg
# │       │           │   │   │   │   ├── story2_2_1.svg
# │       │           │   │   │   │   ├── story2_2_2.svg
# │       │           │   │   │   │   ├── story2_2_3.svg
# │       │           │   │   │   │   ├── story2_3_1.svg
# │       │           │   │   │   │   ├── story2_4_1.svg
# │       │           │   │   │   │   ├── story2_4_2.svg
# │       │           │   │   │   │   ├── story2_4_3.svg
# │       │           │   │   │   │   ├── story2_5_1.svg
# │       │           │   │   │   │   ├── story2_5_2.svg
# │       │           │   │   │   │   ├── story2_5_3.svg
# │       │           │   │   │   │   ├── story2_6_1.svg
# │       │           │   │   │   │   ├── story2_6_2.svg
# │       │           │   │   │   │   ├── story2_6_3.svg
# │       │           │   │   │   │   ├── story3_1_1.svg
# │       │           │   │   │   │   ├── story3_2_1.svg
# │       │           │   │   │   │   ├── story3_2_2.svg
# │       │           │   │   │   │   ├── story3_2_3.svg
# │       │           │   │   │   │   ├── story3_3_1.svg
# │       │           │   │   │   │   ├── story3_3_2.svg
# │       │           │   │   │   │   ├── story3_3_3.svg
# │       │           │   │   │   │   ├── story3_4_1.svg
# │       │           │   │   │   │   ├── story3_5_1.svg
# │       │           │   │   │   │   ├── story3_5_2.svg
# │       │           │   │   │   │   ├── story3_5_3.svg
# │       │           │   │   │   │   ├── story3_6_1.svg
# │       │           │   │   │   │   ├── story3_6_2.svg
# │       │           │   │   │   │   ├── story3_6_3.svg
# │       │           │   │   │   │   ├── story4_1_1.svg
# │       │           │   │   │   │   ├── story4_2_1.svg
# │       │           │   │   │   │   ├── story4_2_2.svg
# │       │           │   │   │   │   ├── story4_2_3.svg
# │       │           │   │   │   │   ├── story4_2_4.svg
# │       │           │   │   │   │   ├── story4_3_1.svg
# │       │           │   │   │   │   ├── story4_3_2.svg
# │       │           │   │   │   │   ├── story4_3_3.svg
# │       │           │   │   │   │   ├── story4_3_4.svg
# │       │           │   │   │   │   ├── story4_4_1.svg
# │       │           │   │   │   │   ├── story5_1_1.svg
# │       │           │   │   │   │   ├── story5_2_1.svg
# │       │           │   │   │   │   ├── story5_2_2.svg
# │       │           │   │   │   │   ├── story5_2_3.svg
# │       │           │   │   │   │   ├── story5_2_4.svg
# │       │           │   │   │   │   ├── story5_2_5.svg
# │       │           │   │   │   │   ├── story5_2_6.svg
# │       │           │   │   │   │   ├── story5_2_7.svg
# │       │           │   │   │   │   ├── story5_3_1.svg
# │       │           │   │   │   │   ├── story5_3_2.svg
# │       │           │   │   │   │   ├── story5_3_3.svg
# │       │           │   │   │   │   ├── story5_3_4.svg
# │       │           │   │   │   │   ├── story5_3_5.svg
# │       │           │   │   │   │   ├── story5_3_6.svg
# │       │           │   │   │   │   ├── story5_4_1.svg
# │       │           │   │   │   │   ├── story5_5_1.svg
# │       │           │   │   │   │   ├── story5_5_2.svg
# │       │           │   │   │   │   ├── story5_5_3.svg
# │       │           │   │   │   │   ├── story5_5_4.svg
# │       │           │   │   │   │   ├── story5_6_1.svg
# │       │           │   │   │   │   ├── story5_6_2.svg
# │       │           │   │   │   │   ├── story5_6_3.svg
# │       │           │   │   │   │   ├── story5_6_4.svg
# │       │           │   │   │   │   ├── story5_6_5.svg
# │       │           │   │   │   │   ├── story5_6_6.svg
# │       │           │   │   │   │   ├── story5_6_7.svg
# │       │           │   │   │   │   └── top_arrow.svg
# │       │           │   │   │   ├── index.gdoc
# │       │           │   │   │   ├── js
# │       │           │   │   │   │   ├── height.js
# │       │           │   │   │   │   ├── jquery-1.10.2.js
# │       │           │   │   │   │   ├── jquery.fatNav.min.js
# │       │           │   │   │   │   ├── jquery.horizonScroll.js
# │       │           │   │   │   │   ├── jquery.touchSwipe.js
# │       │           │   │   │   │   └── sp-nav.js
# │       │           │   │   │   └── story
# │       │           │   │   │       └── index.gdoc
# │       │           │   │   └── story
# │       │           │   │       └── index.gdoc
# │       │           │   ├── w_sjk_feb_mom_kamoshida
# │       │           │   │   ├── chara
# │       │           │   │   │   ├── index.gdoc
# │       │           │   │   │   └── style.css
# │       │           │   │   ├── images
# │       │           │   │   │   ├── action
# │       │           │   │   │   │   ├── action_huki_ko01@2x.png
# │       │           │   │   │   │   ├── action_huki_papa01@2x.png
# │       │           │   │   │   │   ├── action_huki_papa02@2x.png
# │       │           │   │   │   │   ├── action_img_ko01@2x.png
# │       │           │   │   │   │   ├── action_img_ko02@2x.png
# │       │           │   │   │   │   ├── action_img_paoa02@2x.png
# │       │           │   │   │   │   ├── action_img_papa01@2x.png
# │       │           │   │   │   │   ├── action_ko_huki_sp01@2x.png
# │       │           │   │   │   │   ├── action_mitai@2x.png
# │       │           │   │   │   │   ├── action_oyako@2x.png
# │       │           │   │   │   │   ├── action_papa_huki_sp01@2x.png
# │       │           │   │   │   │   ├── action_papa_huki_sp02@2x.png
# │       │           │   │   │   │   └── action_siri@2x.png
# │       │           │   │   │   ├── favicons (1)
# │       │           │   │   │   │   ├── android-chrome-128x128.png
# │       │           │   │   │   │   ├── android-chrome-144x144.png
# │       │           │   │   │   │   ├── android-chrome-152x152.png
# │       │           │   │   │   │   ├── android-chrome-192x192.png
# │       │           │   │   │   │   ├── android-chrome-256x256.png
# │       │           │   │   │   │   ├── android-chrome-36x36.png
# │       │           │   │   │   │   ├── android-chrome-384x384.png
# │       │           │   │   │   │   ├── android-chrome-48x48.png
# │       │           │   │   │   │   ├── android-chrome-512x512.png
# │       │           │   │   │   │   ├── android-chrome-72x72.png
# │       │           │   │   │   │   ├── android-chrome-96x96.png
# │       │           │   │   │   │   ├── apple-touch-icon-114x114.png
# │       │           │   │   │   │   ├── apple-touch-icon-114x114-precomposed.png
# │       │           │   │   │   │   ├── apple-touch-icon-120x120.png
# │       │           │   │   │   │   ├── apple-touch-icon-120x120-precomposed.png
# │       │           │   │   │   │   ├── apple-touch-icon-144x144.png
# │       │           │   │   │   │   ├── apple-touch-icon-144x144-precomposed.png
# │       │           │   │   │   │   ├── apple-touch-icon-152x152.png
# │       │           │   │   │   │   ├── apple-touch-icon-152x152-precomposed.png
# │       │           │   │   │   │   ├── apple-touch-icon-180x180.png
# │       │           │   │   │   │   ├── apple-touch-icon-180x180-precomposed.png
# │       │           │   │   │   │   ├── apple-touch-icon-57x57.png
# │       │           │   │   │   │   ├── apple-touch-icon-57x57-precomposed.png
# │       │           │   │   │   │   ├── apple-touch-icon-60x60.png
# │       │           │   │   │   │   ├── apple-touch-icon-60x60-precomposed.png
# │       │           │   │   │   │   ├── apple-touch-icon-72x72.png
# │       │           │   │   │   │   ├── apple-touch-icon-72x72-precomposed.png
# │       │           │   │   │   │   ├── apple-touch-icon-76x76.png
# │       │           │   │   │   │   ├── apple-touch-icon-76x76-precomposed.png
# │       │           │   │   │   │   ├── apple-touch-icon.png
# │       │           │   │   │   │   ├── apple-touch-icon-precomposed.png
# │       │           │   │   │   │   ├── favicon.ico
# │       │           │   │   │   │   ├── icon-128x128.png
# │       │           │   │   │   │   ├── icon-144x144.png
# │       │           │   │   │   │   ├── icon-152x152.png
# │       │           │   │   │   │   ├── icon-160x160.png
# │       │           │   │   │   │   ├── icon-16x16.png
# │       │           │   │   │   │   ├── icon-192x192.png
# │       │           │   │   │   │   ├── icon-196x196.png
# │       │           │   │   │   │   ├── icon-24x24.png
# │       │           │   │   │   │   ├── icon-256x256.png
# │       │           │   │   │   │   ├── icon-32x32.png
# │       │           │   │   │   │   ├── icon-36x36.png
# │       │           │   │   │   │   ├── icon-384x384.png
# │       │           │   │   │   │   ├── icon-48x48.png
# │       │           │   │   │   │   ├── icon-512x512.png
# │       │           │   │   │   │   ├── icon-72x72.png
# │       │           │   │   │   │   ├── icon-96x96.png
# │       │           │   │   │   │   ├── manifest.json
# │       │           │   │   │   │   ├── site-tile-150x150.png
# │       │           │   │   │   │   ├── site-tile-310x150.png
# │       │           │   │   │   │   ├── site-tile-310x310.png
# │       │           │   │   │   │   └── site-tile-70x70.png
# │       │           │   │   │   ├── header
# │       │           │   │   │   │   ├── header_ko_huki@2x.png
# │       │           │   │   │   │   ├── header_papa_huki@2x.png
# │       │           │   │   │   │   ├── kvs_huki_ko01.png@2x.png
# │       │           │   │   │   │   ├── kvs_huki_papa01.png@2x.png
# │       │           │   │   │   │   ├── kvs_img_ko.png@2x.png
# │       │           │   │   │   │   └── kvs_img_papa.png@2x.png
# │       │           │   │   │   ├── how
# │       │           │   │   │   │   ├── how1@2x.png
# │       │           │   │   │   │   ├── how2@2x.png
# │       │           │   │   │   │   ├── how3@2x.png
# │       │           │   │   │   │   ├── how_kokatai_sp@2x.png
# │       │           │   │   │   │   └── kokatai@2x.png
# │       │           │   │   │   ├── og_img.jpg
# │       │           │   │   │   ├── ranking
# │       │           │   │   │   │   ├── ranking_azamaru.png
# │       │           │   │   │   │   ├── ranking_kusa.png
# │       │           │   │   │   │   ├── ranking_nami.png
# │       │           │   │   │   │   ├── ranking_tapi.png
# │       │           │   │   │   │   └── ranking_tiso.png
# │       │           │   │   │   ├── what's
# │       │           │   │   │   │   ├── what_ko_huki_sp@2x.png
# │       │           │   │   │   │   ├── what_papa_huki_sp01@2x.png
# │       │           │   │   │   │   ├── what_papa_huki_sp02@2x.png
# │       │           │   │   │   │   ├── what's_huki_ko@2x.png
# │       │           │   │   │   │   ├── what's_huki_papa01@2x.png
# │       │           │   │   │   │   ├── what's_huki_papa02@2x.png
# │       │           │   │   │   │   ├── what's_img_ko@2x.png
# │       │           │   │   │   │   └── what's_img_papa@2x.png
# │       │           │   │   │   ├── where
# │       │           │   │   │   │   ├── map@2x.png
# │       │           │   │   │   │   ├── where_huki_ko01@2x.png
# │       │           │   │   │   │   ├── where_huki_ko02@2x.png
# │       │           │   │   │   │   ├── where_huki_papa01@2x.png
# │       │           │   │   │   │   ├── where_huki_papa02@2x.png
# │       │           │   │   │   │   ├── where_img_ko@2x.png
# │       │           │   │   │   │   ├── where_img_papa@2x.png
# │       │           │   │   │   │   ├── where_ko_huki_sp01@2x.png
# │       │           │   │   │   │   ├── where_ko_huki_sp02@2x.png
# │       │           │   │   │   │   ├── where_map_sp@2x.png
# │       │           │   │   │   │   ├── where_papa_huki_sp01@2x.png
# │       │           │   │   │   │   └── where_papa_huki_sp02@2x.png
# │       │           │   │   │   └── why
# │       │           │   │   │       ├── ehy_huki_ko@2x.png
# │       │           │   │   │       ├── kokatais.png
# │       │           │   │   │       ├── why1@2x.png
# │       │           │   │   │       ├── why2@2x.png
# │       │           │   │   │       ├── why3@2x.png
# │       │           │   │   │       ├── why_huki_papa@2x.png
# │       │           │   │   │       ├── why_img_ko@2x.png
# │       │           │   │   │       ├── why_img_papa@2x.png
# │       │           │   │   │       ├── why_ko_huki_sp@2x.png
# │       │           │   │   │       └── why_papa_huki_sp@2x.png
# │       │           │   │   ├── index.gdoc
# │       │           │   │   ├── jquery.inview.min.js
# │       │           │   │   ├── jquery.stickystack.min.js
# │       │           │   │   ├── reset.css
# │       │           │   │   ├── script.js
# │       │           │   │   └── style.css
# │       │           │   ├── w_sjk_feb_mom_nakamura
# │       │           │   │   ├── about.gdoc
# │       │           │   │   ├── css
# │       │           │   │   │   ├── about.css
# │       │           │   │   │   ├── reset.css
# │       │           │   │   │   └── style.css
# │       │           │   │   ├── how.gdoc
# │       │           │   │   ├── images
# │       │           │   │   │   ├── about.png
# │       │           │   │   │   ├── favicon
# │       │           │   │   │   │   ├── android-chrome-144x144.png
# │       │           │   │   │   │   ├── apple-touch-icon.png
# │       │           │   │   │   │   ├── browserconfig.xml
# │       │           │   │   │   │   ├── favicon-16x16.png
# │       │           │   │   │   │   ├── favicon-32x32.png
# │       │           │   │   │   │   ├── favicon.ico
# │       │           │   │   │   │   ├── mstile-150x150.png
# │       │           │   │   │   │   ├── safari-pinned-tab.svg
# │       │           │   │   │   │   └── site.webmanifest
# │       │           │   │   │   ├── GAMEOVER.png
# │       │           │   │   │   ├── game.png
# │       │           │   │   │   ├── game_top.png
# │       │           │   │   │   ├── game_toumei.png
# │       │           │   │   │   ├── h1.png
# │       │           │   │   │   ├── how.png
# │       │           │   │   │   ├── island1_t.png
# │       │           │   │   │   ├── island2.png
# │       │           │   │   │   ├── island2_t.png
# │       │           │   │   │   ├── island3.png
# │       │           │   │   │   ├── island3_t.png
# │       │           │   │   │   ├── island.png
# │       │           │   │   │   ├── kakumon
# │       │           │   │   │   │   ├── m10@2x.png
# │       │           │   │   │   │   ├── m10.png
# │       │           │   │   │   │   ├── m11@2x.png
# │       │           │   │   │   │   ├── m11.png
# │       │           │   │   │   │   ├── m12@2x.png
# │       │           │   │   │   │   ├── m12.png
# │       │           │   │   │   │   ├── m1@2x.png
# │       │           │   │   │   │   ├── m13@2x.png
# │       │           │   │   │   │   ├── m13.png
# │       │           │   │   │   │   ├── m14@2x.png
# │       │           │   │   │   │   ├── m14.png
# │       │           │   │   │   │   ├── m15@2x.png
# │       │           │   │   │   │   ├── m15.png
# │       │           │   │   │   │   ├── m16@2x.png
# │       │           │   │   │   │   ├── m16.png
# │       │           │   │   │   │   ├── m17@2x.png
# │       │           │   │   │   │   ├── m17.png
# │       │           │   │   │   │   ├── m18@2x.png
# │       │           │   │   │   │   ├── m18.png
# │       │           │   │   │   │   ├── m19@2x.png
# │       │           │   │   │   │   ├── m19.png
# │       │           │   │   │   │   ├── m1.png
# │       │           │   │   │   │   ├── m20@2x.png
# │       │           │   │   │   │   ├── m20.png
# │       │           │   │   │   │   ├── m2@2x.png
# │       │           │   │   │   │   ├── m2.png
# │       │           │   │   │   │   ├── m3@2x.png
# │       │           │   │   │   │   ├── m3.png
# │       │           │   │   │   │   ├── m4@2x.png
# │       │           │   │   │   │   ├── m4.png
# │       │           │   │   │   │   ├── m5@2x.png
# │       │           │   │   │   │   ├── m5.png
# │       │           │   │   │   │   ├── m6@2x.png
# │       │           │   │   │   │   ├── m6.png
# │       │           │   │   │   │   ├── m7@2x.png
# │       │           │   │   │   │   ├── m7.png
# │       │           │   │   │   │   ├── m8@2x.png
# │       │           │   │   │   │   ├── m8.png
# │       │           │   │   │   │   ├── m9@2x.png
# │       │           │   │   │   │   └── m9.png
# │       │           │   │   │   ├── konosaito.png
# │       │           │   │   │   ├── m19.png
# │       │           │   │   │   ├── m_blue.png
# │       │           │   │   │   ├── mnokori1.png
# │       │           │   │   │   ├── modoru.png
# │       │           │   │   │   ├── mushi_not.png
# │       │           │   │   │   ├── mushi.png
# │       │           │   │   │   ├── noteback.jpg
# │       │           │   │   │   ├── nuclear.png
# │       │           │   │   │   ├── OGP.jpg
# │       │           │   │   │   ├── oikakeru.png
# │       │           │   │   │   ├── page_back.png
# │       │           │   │   │   ├── pageTop.png
# │       │           │   │   │   ├── plus.png
# │       │           │   │   │   ├── scrool.png
# │       │           │   │   │   ├── search.png
# │       │           │   │   │   ├── shiraberu.png
# │       │           │   │   │   ├── STAGE 1-4.png
# │       │           │   │   │   ├── STAGE 2-4.png
# │       │           │   │   │   ├── STAGE 3-4.png
# │       │           │   │   │   ├── STAGE 4-4.png
# │       │           │   │   │   ├── stage_back1.png
# │       │           │   │   │   ├── stage_back2.png
# │       │           │   │   │   ├── stage_back3.png
# │       │           │   │   │   ├── stage_back4.png
# │       │           │   │   │   ├── stage_back.png
# │       │           │   │   │   ├── start.png
# │       │           │   │   │   ├── suoerman_4.png
# │       │           │   │   │   ├── superman.png
# │       │           │   │   │   ├── top_back.png
# │       │           │   │   │   ├── umeru.png
# │       │           │   │   │   ├── where.png
# │       │           │   │   │   └── why.png
# │       │           │   │   ├── index.gdoc
# │       │           │   │   ├── js
# │       │           │   │   │   ├── jquery.inview.min.js
# │       │           │   │   │   ├── matter.min.js
# │       │           │   │   │   └── t.min.js
# │       │           │   │   ├── matter-js-master
# │       │           │   │   │   └── matter-js-master
# │       │           │   │   │       ├── bower.json
# │       │           │   │   │       ├── build
# │       │           │   │   │       │   ├── matter.js
# │       │           │   │   │       │   └── matter.min.js
# │       │           │   │   │       ├── CHANGELOG.md
# │       │           │   │   │       ├── CONTRIBUTING.md
# │       │           │   │   │       ├── demo
# │       │           │   │   │       │   ├── img
# │       │           │   │   │       │   │   ├── background.png
# │       │           │   │   │       │   │   ├── ball.png
# │       │           │   │   │       │   │   ├── block-2.png
# │       │           │   │   │       │   │   ├── block.png
# │       │           │   │   │       │   │   ├── box.png
# │       │           │   │   │       │   │   ├── rock.png
# │       │           │   │   │       │   │   └── wall-bg.jpg
# │       │           │   │   │       │   ├── index.gdoc
# │       │           │   │   │       │   ├── js
# │       │           │   │   │       │   │   ├── Compare.js
# │       │           │   │   │       │   │   └── Demo.js
# │       │           │   │   │       │   ├── lib
# │       │           │   │   │       │   │   ├── decomp.js
# │       │           │   │   │       │   │   ├── jquery-1.11.0.min.js
# │       │           │   │   │       │   │   ├── matter-tools.demo.js
# │       │           │   │   │       │   │   ├── matter-tools.gui.js
# │       │           │   │   │       │   │   ├── matter-tools.inspector.js
# │       │           │   │   │       │   │   ├── matter-wrap.js
# │       │           │   │   │       │   │   └── pathseg.js
# │       │           │   │   │       │   └── svg
# │       │           │   │   │       │       ├── iconmonstr-check-mark-8-icon.svg
# │       │           │   │   │       │       ├── iconmonstr-direction-4-icon.svg
# │       │           │   │   │       │       ├── iconmonstr-paperclip-2-icon.svg
# │       │           │   │   │       │       ├── iconmonstr-puzzle-icon.svg
# │       │           │   │   │       │       ├── iconmonstr-user-icon.svg
# │       │           │   │   │       │       ├── svg.svg
# │       │           │   │   │       │       └── terrain.svg
# │       │           │   │   │       ├── examples
# │       │           │   │   │       │   ├── airFriction.js
# │       │           │   │   │       │   ├── avalanche.js
# │       │           │   │   │       │   ├── ballPool.js
# │       │           │   │   │       │   ├── bridge.js
# │       │           │   │   │       │   ├── broadphase.js
# │       │           │   │   │       │   ├── car.js
# │       │           │   │   │       │   ├── catapult.js
# │       │           │   │   │       │   ├── chains.js
# │       │           │   │   │       │   ├── circleStack.js
# │       │           │   │   │       │   ├── cloth.js
# │       │           │   │   │       │   ├── collisionFiltering.js
# │       │           │   │   │       │   ├── compositeManipulation.js
# │       │           │   │   │       │   ├── compound.js
# │       │           │   │   │       │   ├── compoundStack.js
# │       │           │   │   │       │   ├── concave.js
# │       │           │   │   │       │   ├── constraints.js
# │       │           │   │   │       │   ├── doublePendulum.js
# │       │           │   │   │       │   ├── events.js
# │       │           │   │   │       │   ├── friction.js
# │       │           │   │   │       │   ├── gravity.js
# │       │           │   │   │       │   ├── gyro.js
# │       │           │   │   │       │   ├── index.js
# │       │           │   │   │       │   ├── manipulation.js
# │       │           │   │   │       │   ├── mixed.js
# │       │           │   │   │       │   ├── newtonsCradle.js
# │       │           │   │   │       │   ├── pyramid.js
# │       │           │   │   │       │   ├── ragdoll.js
# │       │           │   │   │       │   ├── raycasting.js
# │       │           │   │   │       │   ├── restitution.js
# │       │           │   │   │       │   ├── rounded.js
# │       │           │   │   │       │   ├── sensors.js
# │       │           │   │   │       │   ├── sleeping.js
# │       │           │   │   │       │   ├── slingshot.js
# │       │           │   │   │       │   ├── softBody.js
# │       │           │   │   │       │   ├── sprites.js
# │       │           │   │   │       │   ├── stack.js
# │       │           │   │   │       │   ├── staticFriction.js
# │       │           │   │   │       │   ├── stress2.js
# │       │           │   │   │       │   ├── stress.js
# │       │           │   │   │       │   ├── svg.js
# │       │           │   │   │       │   ├── terrain.js
# │       │           │   │   │       │   ├── timescale.js
# │       │           │   │   │       │   ├── views.js
# │       │           │   │   │       │   └── wreckingBall.js
# │       │           │   │   │       ├── Gulpfile.js
# │       │           │   │   │       ├── LICENSE
# │       │           │   │   │       ├── package.json
# │       │           │   │   │       ├── package-lock.json
# │       │           │   │   │       ├── README.md
# │       │           │   │   │       ├── src
# │       │           │   │   │       │   ├── body
# │       │           │   │   │       │   │   ├── Body.js
# │       │           │   │   │       │   │   ├── Composite.js
# │       │           │   │   │       │   │   └── World.js
# │       │           │   │   │       │   ├── collision
# │       │           │   │   │       │   │   ├── Detector.js
# │       │           │   │   │       │   │   ├── Grid.js
# │       │           │   │   │       │   │   ├── Pair.js
# │       │           │   │   │       │   │   ├── Pairs.js
# │       │           │   │   │       │   │   ├── Query.js
# │       │           │   │   │       │   │   ├── Resolver.js
# │       │           │   │   │       │   │   └── SAT.js
# │       │           │   │   │       │   ├── constraint
# │       │           │   │   │       │   │   ├── Constraint.js
# │       │           │   │   │       │   │   └── MouseConstraint.js
# │       │           │   │   │       │   ├── core
# │       │           │   │   │       │   │   ├── Common.js
# │       │           │   │   │       │   │   ├── Engine.js
# │       │           │   │   │       │   │   ├── Events.js
# │       │           │   │   │       │   │   ├── Matter.js
# │       │           │   │   │       │   │   ├── Metrics.js
# │       │           │   │   │       │   │   ├── Mouse.js
# │       │           │   │   │       │   │   ├── Plugin.js
# │       │           │   │   │       │   │   ├── Runner.js
# │       │           │   │   │       │   │   └── Sleeping.js
# │       │           │   │   │       │   ├── factory
# │       │           │   │   │       │   │   ├── Bodies.js
# │       │           │   │   │       │   │   └── Composites.js
# │       │           │   │   │       │   ├── geometry
# │       │           │   │   │       │   │   ├── Axes.js
# │       │           │   │   │       │   │   ├── Bounds.js
# │       │           │   │   │       │   │   ├── Svg.js
# │       │           │   │   │       │   │   ├── Vector.js
# │       │           │   │   │       │   │   └── Vertices.js
# │       │           │   │   │       │   ├── module
# │       │           │   │   │       │   │   ├── license.js
# │       │           │   │   │       │   │   └── main.js
# │       │           │   │   │       │   └── render
# │       │           │   │   │       │       ├── Render.js
# │       │           │   │   │       │       └── RenderPixi.js
# │       │           │   │   │       ├── test
# │       │           │   │   │       │   ├── Examples.spec.js
# │       │           │   │   │       │   └── TestTools.js
# │       │           │   │   │       ├── webpack.config.js
# │       │           │   │   │       ├── webpack.examples.config.js
# │       │           │   │   │       └── yuidoc.json
# │       │           │   │   ├── where.gdoc
# │       │           │   │   └── why.gdoc
# │       │           │   ├── w_yamaguchi_sumida
# │       │           │   │   ├── cfe.sakura.ne.jp-w_yamaguchi_sumida-20200120-121754-820.wpress
# │       │           │   │   └── WPで構築、All-in-One WP Migrationでインポート
# │       │           │   └── w_yic_yamamoto
# │       │           │       ├── character.gdoc
# │       │           │       ├── css
# │       │           │       │   └── bootstrap-4.3.1.css
# │       │           │       ├── game
# │       │           │       │   ├── builder_config.json
# │       │           │       │   ├── credits.gdoc
# │       │           │       │   ├── data
# │       │           │       │   │   ├── bgimage
# │       │           │       │   │   │   ├── blue.png
# │       │           │       │   │   │   ├── ice.png
# │       │           │       │   │   │   ├── img
# │       │           │       │   │   │   │   ├── omake_title.jpg
# │       │           │       │   │   │   │   ├── orenzi.jpg
# │       │           │       │   │   │   │   ├── rain.jpg
# │       │           │       │   │   │   │   ├── riving.jpg
# │       │           │       │   │   │   │   ├── road.jpg
# │       │           │       │   │   │   │   ├── room.jpg
# │       │           │       │   │   │   │   ├── shadow.jpg
# │       │           │       │   │   │   │   └── sky.jpg
# │       │           │       │   │   │   ├── img2
# │       │           │       │   │   │   │   ├── cg_2.jpg
# │       │           │       │   │   │   │   ├── end_2.jpg
# │       │           │       │   │   │   │   └── end2.jpg
# │       │           │       │   │   │   ├── jpg
# │       │           │       │   │   │   │   ├── black.jpg
# │       │           │       │   │   │   │   └── title.jpg
# │       │           │       │   │   │   ├── sea.png
# │       │           │       │   │   │   └── space.png
# │       │           │       │   │   ├── bgm
# │       │           │       │   │   │   ├── modorenaiyuugure.m4a
# │       │           │       │   │   │   ├── modorenaiyuugure.ogg
# │       │           │       │   │   │   ├── music.m4a
# │       │           │       │   │   │   ├── music.ogg
# │       │           │       │   │   │   ├── nemurinitsukusekai.m4a
# │       │           │       │   │   │   ├── nemurinitsukusekai.ogg
# │       │           │       │   │   │   ├── rain1.m4a
# │       │           │       │   │   │   ├── rain1.ogg
# │       │           │       │   │   │   ├── tsukinomiyako_nostalgia_.m4a
# │       │           │       │   │   │   └── tsukinomiyako_nostalgia_.ogg
# │       │           │       │   │   ├── fgimage
# │       │           │       │   │   │   ├── chara
# │       │           │       │   │   │   │   ├── 1
# │       │           │       │   │   │   │   │   ├── komati2.png
# │       │           │       │   │   │   │   │   ├── komati3.png
# │       │           │       │   │   │   │   │   ├── komati4.png
# │       │           │       │   │   │   │   │   ├── komati6.png
# │       │           │       │   │   │   │   │   ├── komati7.png
# │       │           │       │   │   │   │   │   ├── komati8.png
# │       │           │       │   │   │   │   │   └── komati.png
# │       │           │       │   │   │   │   ├── 2
# │       │           │       │   │   │   │   │   ├── fee2.png
# │       │           │       │   │   │   │   │   ├── fee3.png
# │       │           │       │   │   │   │   │   ├── fee4.png
# │       │           │       │   │   │   │   │   └── fee.png
# │       │           │       │   │   │   │   └── 3
# │       │           │       │   │   │   │       ├── together2.png
# │       │           │       │   │   │   │       ├── together3.png
# │       │           │       │   │   │   │       ├── together4.png
# │       │           │       │   │   │   │       ├── together5.png
# │       │           │       │   │   │   │       ├── together6.png
# │       │           │       │   │   │   │       └── together.png
# │       │           │       │   │   │   └── default
# │       │           │       │   │   │       ├── ice.jpg
# │       │           │       │   │   │       ├── sea.jpg
# │       │           │       │   │   │       └── space.jpg
# │       │           │       │   │   ├── image
# │       │           │       │   │   │   ├── 1.png
# │       │           │       │   │   │   ├── 2.png
# │       │           │       │   │   │   ├── 3.png
# │       │           │       │   │   │   ├── 4.png
# │       │           │       │   │   │   ├── button
# │       │           │       │   │   │   │   ├── auto2.png
# │       │           │       │   │   │   │   ├── auto.png
# │       │           │       │   │   │   │   ├── backlog2.png
# │       │           │       │   │   │   │   ├── backlog.png
# │       │           │       │   │   │   │   ├── config2.png
# │       │           │       │   │   │   │   ├── config.png
# │       │           │       │   │   │   │   ├── fullscreen2.png
# │       │           │       │   │   │   │   ├── fullscreen.png
# │       │           │       │   │   │   │   ├── load2.png
# │       │           │       │   │   │   │   ├── load.png
# │       │           │       │   │   │   │   ├── menu2.png
# │       │           │       │   │   │   │   ├── menu.png
# │       │           │       │   │   │   │   ├── quickload2.png
# │       │           │       │   │   │   │   ├── quickload.png
# │       │           │       │   │   │   │   ├── quicksave2.png
# │       │           │       │   │   │   │   ├── quicksave.png
# │       │           │       │   │   │   │   ├── save2.png
# │       │           │       │   │   │   │   ├── save.png
# │       │           │       │   │   │   │   ├── skip2.png
# │       │           │       │   │   │   │   ├── skip.png
# │       │           │       │   │   │   │   ├── Thumbs.db
# │       │           │       │   │   │   │   ├── title2.png
# │       │           │       │   │   │   │   ├── title.png
# │       │           │       │   │   │   │   ├── window2.png
# │       │           │       │   │   │   │   └── window.png
# │       │           │       │   │   │   ├── config
# │       │           │       │   │   │   │   ├── arrow_next.png
# │       │           │       │   │   │   │   ├── arrow_prev.png
# │       │           │       │   │   │   │   ├── bg_config.jpg
# │       │           │       │   │   │   │   ├── button_unread_off.png
# │       │           │       │   │   │   │   ├── button_unread_on.png
# │       │           │       │   │   │   │   ├── c_btn_back2.png
# │       │           │       │   │   │   │   ├── c_btn_back.png
# │       │           │       │   │   │   │   ├── c_btn.png
# │       │           │       │   │   │   │   ├── c_set.png
# │       │           │       │   │   │   │   ├── c_uts_off.png
# │       │           │       │   │   │   │   ├── c_uts_on.png
# │       │           │       │   │   │   │   ├── label_cg.png
# │       │           │       │   │   │   │   ├── label_config.png
# │       │           │       │   │   │   │   ├── label_recollection.png
# │       │           │       │   │   │   │   ├── menu_button_close2.png
# │       │           │       │   │   │   │   ├── menu_button_close.png
# │       │           │       │   │   │   │   └── message_box.png
# │       │           │       │   │   │   ├── no1.png
# │       │           │       │   │   │   ├── no2.png
# │       │           │       │   │   │   ├── noimage.png
# │       │           │       │   │   │   └── title
# │       │           │       │   │   │       ├── button_cg.gif
# │       │           │       │   │   │       ├── button_config.gif
# │       │           │       │   │   │       ├── button_load.gif
# │       │           │       │   │   │       ├── button_replay.gif
# │       │           │       │   │   │       └── button_start.gif
# │       │           │       │   │   ├── others
# │       │           │       │   │   │   ├── font_1_ant-kaku.ttf
# │       │           │       │   │   │   └── plugin
# │       │           │       │   │   │       ├── theme_kopanda_02
# │       │           │       │   │   │       │   ├── builder.json
# │       │           │       │   │   │       │   ├── config.ks
# │       │           │       │   │   │       │   ├── html
# │       │           │       │   │   │       │   │   ├── backlog.gdoc
# │       │           │       │   │   │       │   │   ├── load.gdoc
# │       │           │       │   │   │       │   │   ├── menu.gdoc
# │       │           │       │   │   │       │   │   └── save.gdoc
# │       │           │       │   │   │       │   ├── image
# │       │           │       │   │   │       │   │   ├── button
# │       │           │       │   │   │       │   │   │   ├── auto2.png
# │       │           │       │   │   │       │   │   │   ├── auto.png
# │       │           │       │   │   │       │   │   │   ├── close2.png
# │       │           │       │   │   │       │   │   │   ├── close.png
# │       │           │       │   │   │       │   │   │   ├── load2.png
# │       │           │       │   │   │       │   │   │   ├── load.png
# │       │           │       │   │   │       │   │   │   ├── log2.png
# │       │           │       │   │   │       │   │   │   ├── log.png
# │       │           │       │   │   │       │   │   │   ├── menu2.png
# │       │           │       │   │   │       │   │   │   ├── menu.png
# │       │           │       │   │   │       │   │   │   ├── qload2.png
# │       │           │       │   │   │       │   │   │   ├── qload.png
# │       │           │       │   │   │       │   │   │   ├── qsave2.png
# │       │           │       │   │   │       │   │   │   ├── qsave.png
# │       │           │       │   │   │       │   │   │   ├── save2.png
# │       │           │       │   │   │       │   │   │   ├── save.png
# │       │           │       │   │   │       │   │   │   ├── screen2.png
# │       │           │       │   │   │       │   │   │   ├── screen.png
# │       │           │       │   │   │       │   │   │   ├── skip2.png
# │       │           │       │   │   │       │   │   │   ├── skip.png
# │       │           │       │   │   │       │   │   │   ├── sleep2.png
# │       │           │       │   │   │       │   │   │   ├── sleep.png
# │       │           │       │   │   │       │   │   │   ├── Thumbs.db
# │       │           │       │   │   │       │   │   │   ├── title2.png
# │       │           │       │   │   │       │   │   │   └── title.png
# │       │           │       │   │   │       │   │   ├── config
# │       │           │       │   │   │       │   │   │   ├── bg_config.jpg
# │       │           │       │   │   │       │   │   │   ├── c_btn_back2.gif
# │       │           │       │   │   │       │   │   │   ├── c_btn_back.gif
# │       │           │       │   │   │       │   │   │   ├── c_btn.png
# │       │           │       │   │   │       │   │   │   ├── c_set.png
# │       │           │       │   │   │       │   │   │   ├── c_uts_off.png
# │       │           │       │   │   │       │   │   │   └── c_uts_on.png
# │       │           │       │   │   │       │   │   ├── frame_message.png
# │       │           │       │   │   │       │   │   └── system
# │       │           │       │   │   │       │   │       ├── arrow_down.png
# │       │           │       │   │   │       │   │       ├── arrow_next.png
# │       │           │       │   │   │       │   │       ├── arrow_prev.png
# │       │           │       │   │   │       │   │       ├── arrow_up.png
# │       │           │       │   │   │       │   │       ├── menu_bg.jpg
# │       │           │       │   │   │       │   │       ├── menu_button_close2.png
# │       │           │       │   │   │       │   │       ├── menu_button_close.png
# │       │           │       │   │   │       │   │       ├── menu_button_load2.gif
# │       │           │       │   │   │       │   │       ├── menu_button_load.gif
# │       │           │       │   │   │       │   │       ├── menu_button_save2.gif
# ...
# │       │   │   │   ├── 吉川 薫.zip
# │       │   │   │   ├── 株式会社コトブキ様提出
# │       │   │   │   │   └── 作品のみフォルダ
# │       │   │   │   │       ├── clientwork_丸山美幸.pdf
# │       │   │   │   │       ├── fryer_A4_fix_ol_小川 詩音_compressed.pdf
# │       │   │   │   │       ├── kotobukifarmdepo_sama_poster_210710_02_fukuenaoto_2106.pdf
# │       │   │   │   │       ├── kotobukifarm＿香川昌美_compressed.pdf
# │       │   │   │   │       ├── kotobuki_渡辺 淳志.pdf
# │       │   │   │   │       ├── outline_kotobukifarmdepo_poster_齊藤 武蔵(表のみ).pdf
# │       │   │   │   │       ├── モンロー ケイ.pdf
# │       │   │   │   │       ├── poster_1_金城 実来.pdf
# │       │   │   │   │       ├── poster_2金城 実来_compressed.pdf
# │       │   │   │   │       ├── poster_3_金城 実来.pdf
# │       │   │   │   │       ├── 制作物_ol_廣島 楓花.pdf
# │       │   │   │   │       ├── クライアントワーク制作物_新家 早知.pdf
# │       │   │   │   │       ├── 堀池 杏.pdf
# │       │   │   │   │       ├── クライアントワーク 夏秋いちご_吉川 薫.pdf
# │       │   │   │   │       ├── 夏秋いちご_大迫南海.pdf
# │       │   │   │   │       ├── クライアントワーク大来文音提出.pdf
# │       │   │   │   │       ├── 寿ファームデポ様　Ａ４チラシ勝谷 光莉.pdf
# │       │   │   │   │       ├── 川島 麻緒.pdf
# │       │   │   │   │       ├── 市丸 瑶子.pdf
# │       │   │   │   │       ├── 栗栖 采見.pdf
# │       │   │   │   │       ├── コトブキファームデポ様_山岡 敬弘_.pdf
# │       │   │   │   │       ├── コトブキファームデポ様_金子 駿.pdf
# │       │   │   │   │       ├── 渡邊歩実_PDFデータ.pdf
# │       │   │   │   │       ├── 渡邊 美帆.pdf
# │       │   │   │   │       ├── ポスターデザイン_矢部 美果子.pdf
# │       │   │   │   │       ├── クライアントワーク課題_角田翼(表のみ).pdf
# │       │   │   │   │       ├── クライアントワーク＿チラシデザイン._鈴木 彩夏(表のみ).pdf
# │       │   │   │   │       ├── 長谷川 菜月.pdf
# │       │   │   │   │       └── クライアントワーク_高橋果子.pdf
# │       │   │   │   └── クライアントワーク質問シート .gsheet
# │       │   │   └── DAY9：個別面談
# │       │   │       ├── 資料
# │       │   │       └── 超実践6月生DAY9面談調整.gsheet
# │       │   ├── 超実践2021年8月生
# │       │   │   ├── グラフィック
# │       │   │   │   ├── 天草市役所様ご提出
# │       │   │   │   │   ├── 佐藤 佑菜
# │       │   │   │   │   │   ├── amakusa.pdf
# │       │   │   │   │   │   └── ppt_satoyuna.pdf
# │       │   │   │   │   ├── 北嶋さらら
# │       │   │   │   │   │   ├── amakusa_outline.pdf
# │       │   │   │   │   │   └── 天草プレゼン資料.pdf
# │       │   │   │   │   ├── 古井 皓大
# │       │   │   │   │   │   ├── 天草市企業誘致プレゼン.gslides
# │       │   │   │   │   │   └── 天草市企業誘致チラシ.png
# │       │   │   │   │   ├── 向田 祐平
# │       │   │   │   │   │   ├── 天草市様企業誘致チラシ.pdf
# │       │   │   │   │   │   └── 天草市様_企業誘致チラシご提案r5.pdf
# │       │   │   │   │   ├── 土橋 奈々
# │       │   │   │   │   │   ├── amakusa (1).pdf
# │       │   │   │   │   │   └── ポスター提案.pdf
# │       │   │   │   │   ├── 城森 直美
# │       │   │   │   │   │   ├── 天草市様へのご提案.pdf
# │       │   │   │   │   │   └── 天草誘致A4チラシ_ol.pdf
# │       │   │   │   │   ├── 小山 実里
# │       │   │   │   │   │   ├── amakusa_outline (1).pdf
# │       │   │   │   │   │   └── プレゼン資料_小山実里.pdf
# │       │   │   │   │   ├── 山口 花
# │       │   │   │   │   │   ├── 天草サテライトオフィスプレゼン.pdf
# │       │   │   │   │   │   └── 天草サテライトオフィスチラシ提出用.pdf
# │       │   │   │   │   ├── 岡野 有夏
# │       │   │   │   │   │   ├── 2021.9.12 天草市プレゼンpdf版.pdf
# │       │   │   │   │   │   └── 天草市クライアントワーク完成版アウトライン.pdf
# │       │   │   │   │   ├── 廣次 桃花
# │       │   │   │   │   │   ├── チラシデザインOL.pdf
# │       │   │   │   │   │   └── 天草誘致提案プレゼン.key
# │       │   │   │   │   ├── 徳山 美沙
# │       │   │   │   │   │   ├── デザインA案_徳山美沙.pdf
# │       │   │   │   │   │   ├── デザインB案_徳山美沙.pdf
# │       │   │   │   │   │   └── プレゼン資料（徳山美沙）.pdf
# │       │   │   │   │   ├── 樋口 奈穂
# │       │   │   │   │   │   ├── flyer.pdf
# │       │   │   │   │   │   └── 天草市企業誘致チラシ提案.pdf
# │       │   │   │   │   ├── 櫻井萌恵
# │       │   │   │   │   │   ├── 天草市企業立地提案デザイン.pdf
# │       │   │   │   │   │   └── 天草市企業誘致提案資料.key
# │       │   │   │   │   ├── 武藤 悠介
# │       │   │   │   │   │   ├── 天草市企業誘致チラシ_outline.pdf
# │       │   │   │   │   │   └── 天草市企業誘致プレゼン資料.key
# │       │   │   │   │   ├── 澤岻 和乃
# │       │   │   │   │   │   ├── amakusa_backside_finaldraft.pdf
# │       │   │   │   │   │   ├── amakusa_finaldraft.pdf
# │       │   │   │   │   │   └── プレゼン資料.pdf
# │       │   │   │   │   ├──  澤栁 友里
# │       │   │   │   │   │   ├── 天草市企業誘致プロジェクト.pdf
# │       │   │   │   │   │   └── 天草市企業誘致ポスター案.pdf
# │       │   │   │   │   ├── 濱本 莉沙
# │       │   │   │   │   │   ├── 天草チラシプレゼンボード.pdf
# │       │   │   │   │   │   └── 天草市企業誘致チラシデザイン（トンボあり）.pdf
# │       │   │   │   │   ├── 米良春奈
# │       │   │   │   │   │   ├── A4_omote.pdf
# │       │   │   │   │   │   ├── A4_ura.pdf
# │       │   │   │   │   │   └── ご提案資料.pdf
# │       │   │   │   │   ├── 船津 里菜
# │       │   │   │   │   │   ├── amakusachirashi_Funatsu_Rina.pdf
# │       │   │   │   │   │   └── ppt_Funastu_Rina.pdf
# │       │   │   │   │   ├── 花田歩美
# │       │   │   │   │   │   ├── 企業誘致_プレゼン_20210912.pdf
# │       │   │   │   │   │   ├── 企業誘致_チラシ_B案.pdf
# │       │   │   │   │   │   ├── 企業誘致_チラシ_C案.pdf
# │       │   │   │   │   │   └── 企業誘致_チラシ_メイン案.pdf
# │       │   │   │   │   ├── 近藤 竣介
# │       │   │   │   │   │   ├── 天草市_誘致チラシ _デザイン.pdf
# │       │   │   │   │   │   └── 天草_誘致チラシ_プレゼン資料.pdf
# │       │   │   │   │   ├── 鈴木 勇輝
# │       │   │   │   │   │   ├── 天草表面.pdf
# │       │   │   │   │   │   ├── 天草表面春版.pdf
# │       │   │   │   │   │   ├── 天草表面秋版.pdf
# │       │   │   │   │   │   ├── 天草裏面.pdf
# │       │   │   │   │   │   └── 天草プレゼン資料 (1).pdf
# │       │   │   │   │   ├── 長岡 絢子
# │       │   │   │   │   │   ├── amakusa_omote.pdf
# │       │   │   │   │   │   ├── amakusa_ura.pdf
# │       │   │   │   │   │   └── presentation.pdf
# │       │   │   │   │   └── 長野 明穂
# │       │   │   │   │       ├── プレゼン.pdf
# │       │   │   │   │       └── 天草市チラシ.pdf
# │       │   │   │   ├── 相互評価表 DAY2.gsheet
# │       │   │   │   ├── グラフィック課題エラー
# │       │   │   │   │   ├── 佐藤 佑菜
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.49.53.png
# │       │   │   │   │   │   └── スクリーンショット 2021-09-16 15.50.00.png
# │       │   │   │   │   ├── 北嶋さらら
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 16.00.04.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 16.00.12.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 16.00.18.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 16.00.23.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 16.00.28.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 16.00.32.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 16.00.37.png
# │       │   │   │   │   │   └── スクリーンショット 2021-09-16 16.00.42.png
# │       │   │   │   │   ├── 古井 皓大
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 16.14.14.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 16.14.22.png
# │       │   │   │   │   │   └── スクリーンショット 2021-09-16 16.14.29.png
# │       │   │   │   │   ├── 土橋 奈々
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 16.20.05.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 16.20.11.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 16.20.15.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 16.20.20.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 16.20.24.png
# │       │   │   │   │   │   └── スクリーンショット 2021-09-16 16.20.35.png
# │       │   │   │   │   ├── 城森 直美
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 16.17.22.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 16.17.27.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 16.17.32.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 16.17.36.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 16.17.40.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 16.17.46.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 16.17.50.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 16.17.55.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 16.18.00.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 16.18.04.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 16.18.09.png
# │       │   │   │   │   │   └── スクリーンショット 2021-09-16 16.18.14.png
# │       │   │   │   │   ├── 山口花
# │       │   │   │   │   │   ├── 山口 花1.png
# │       │   │   │   │   │   ├── 山口 花2.png
# │       │   │   │   │   │   ├── 山口 花3.png
# │       │   │   │   │   │   ├── 山口 花4.png
# │       │   │   │   │   │   ├── 山口 花5.png
# │       │   │   │   │   │   ├── 山口 花6.png
# │       │   │   │   │   │   └── 山口 花7.png
# │       │   │   │   │   ├── 廣次 桃花
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 16.06.46.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 16.06.55.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 16.06.59.png
# │       │   │   │   │   │   └── スクリーンショット 2021-09-16 16.07.04.png
# │       │   │   │   │   ├── 徳山 美沙
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.44.19.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.44.24.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.44.29.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.44.36.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.44.45.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.44.49.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.44.54.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.44.59.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.45.04.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.45.09.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.45.14.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.45.19.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.45.24.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.45.30.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.45.35.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.45.40.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.45.45.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.45.50.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.45.55.png
# │       │   │   │   │   │   └── スクリーンショット 2021-09-16 15.46.03.png
# │       │   │   │   │   ├── 樋口 奈穂
# │       │   │   │   │   │   ├── 樋口 奈穂1.png
# │       │   │   │   │   │   ├── 樋口 奈穂2.png
# │       │   │   │   │   │   └── 樋口 奈穂3.png
# │       │   │   │   │   ├── 櫻井萌恵
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 16.08.29.png
# │       │   │   │   │   │   └── スクリーンショット 2021-09-16 16.08.33.png
# │       │   │   │   │   ├── 武藤 悠介.png
# │       │   │   │   │   ├── 澤岻 和乃
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 16.28.38.png
# │       │   │   │   │   │   └── スクリーンショット 2021-09-16 16.28.44.png
# │       │   │   │   │   ├── 澤栁 友里
# │       │   │   │   │   │   ├── 澤栁 友里1.png
# │       │   │   │   │   │   └── 澤栁 友里2.png
# │       │   │   │   │   ├── 濱本 莉沙.png
# │       │   │   │   │   ├── 米良 春奈.png
# │       │   │   │   │   ├── 花田 歩美
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.48.47.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.49.06.png
# │       │   │   │   │   │   └── スクリーンショット 2021-09-16 15.49.18.png
# │       │   │   │   │   ├── 近藤 竣介
# │       │   │   │   │   │   ├── 近藤 竣介1.png
# │       │   │   │   │   │   ├── 近藤 竣介2.png
# │       │   │   │   │   │   ├── 近藤 竣介3.png
# │       │   │   │   │   │   ├── 近藤 竣介4.png
# │       │   │   │   │   │   ├── 近藤 竣介5.png
# │       │   │   │   │   │   └── 近藤 竣介6.png
# │       │   │   │   │   ├── 鈴木 勇輝
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.28.00.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.28.05.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.28.12.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.28.35.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.28.44.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.29.04.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.29.09.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.29.14.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.29.46.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.29.51.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.29.57.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.30.15.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.30.21.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.30.26.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.30.32.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.30.37.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.30.42.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.30.48.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.30.53.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.30.57.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.31.01.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.31.05.png
# │       │   │   │   │   │   ├── スクリーンショット 2021-09-16 15.31.10.png
# │       │   │   │   │   │   └── スクリーンショット 2021-09-16 15.31.24.png
# │       │   │   │   │   ├── 長岡 絢子.png
# │       │   │   │   │   └── 長野 明穂
# │       │   │   │   │       ├── スクリーンショット 2021-09-16 15.56.23.png
# │       │   │   │   │       ├── スクリーンショット 2021-09-16 15.56.28.png
# │       │   │   │   │       ├── スクリーンショット 2021-09-16 15.56.34.png
# │       │   │   │   │       ├── スクリーンショット 2021-09-16 15.56.39.png
# │       │   │   │   │       ├── スクリーンショット 2021-09-16 15.56.44.png
# │       │   │   │   │       ├── スクリーンショット 2021-09-16 15.56.50.png
# │       │   │   │   │       ├── スクリーンショット 2021-09-16 15.56.56.png
# │       │   │   │   │       ├── スクリーンショット 2021-09-16 15.57.02.png
# │       │   │   │   │       ├── スクリーンショット 2021-09-16 15.57.07.png
# │       │   │   │   │       ├── スクリーンショット 2021-09-16 15.57.13.png
# │       │   │   │   │       ├── スクリーンショット 2021-09-16 15.57.18.png
# │       │   │   │   │       ├── スクリーンショット 2021-09-16 15.57.23.png
# │       │   │   │   │       ├── スクリーンショット 2021-09-16 15.57.27.png
# │       │   │   │   │       ├── スクリーンショット 2021-09-16 15.57.33.png
# │       │   │   │   │       ├── スクリーンショット 2021-09-16 15.57.39.png
# │       │   │   │   │       ├── スクリーンショット 2021-09-16 15.57.45.png
# │       │   │   │   │       └── スクリーンショット 2021-09-16 15.57.50.png
# │       │   │   │   └── クライアントワーク質問シート.gsheet
# │       │   │   ├── DAY9
# │       │   │   │   └── 超実践8月生DAY9.gsheet
# │       │   │   ├── Web
# │       │   │   │   ├── マイナビ写真素材管理表.gsheet
# │       │   │   │   └── クライアントワーク質問シート.gsheet
# │       │   │   └── 相互評価表 DAY3.gsheet
# │       │   ├── 超実践受講生就転職状況.gsheet
# │       │   ├── 超実践担当割_220131.gsheet
# │       │   └── 超実践業務引き継ぎ
# │       │       ├── 超実践　slack投稿例.gdoc
# │       │       └── 超実践運用マニュアル.gdoc
# │       ├── セミナー開始前.gslides
# │       ├── 雛形
# │       │   ├── サムネイル
# │       │   │   ├── JSS画像サイズ.jpg
# │       │   │   ├── サムネイル.psd
# │       │   │   ├── sample-thumnail.jpg
# │       │   │   ├── _xworksjssimagetemp.psd
# │       │   │   ├── _xworksjssimaデジタルハリウッドのWebサイト運営アシスタント募集.psd
# │       │   │   └── _xworksjssimaデジタルハリウッドのWebサイト運営アシスタント募集！.psd
# │       │   ├── メモ-190515.txt
# │       │   ├── old
# │       │   │   ├── マッチング【〇〇様】案件名応募者リスト_yymmdd
# │       │   │   └── マッチング【管理用】案件名応募者リスト_yymmdd
# │       │   ├── 【xWORKS】マッチングシート.gsheet
# │       │   ├── 〇〇案件問合せ一覧表.gsheet
# │       │   ├── マッチング【〇〇様】案件名応募者リスト_yymmdd.gsheet
# │       │   ├── ユニット【〇〇様】案件名応募者リスト_yymmdd.gsheet
# │       │   ├── マッチング【管理用】案件名応募者リスト_yymmdd.gsheet
# │       │   ├── ユニット【管理用】案件名応募者リスト_yymmdd.gsheet
# │       │   ├── 選考結果報告メール雛形.txt
# │       │   └── 【メール雛形】新規問合せ返信営業.gdoc
# │       ├── 面談
# │       │   ├── ポートフォリオ
# │       │   │   └── 小田切美音
# │       │   │       └── 紙ポートフォリオ_outline_ver2.pdf
# │       │   ├── マイナビジョブ20's 履歴書・職務経歴書テンプレートダウンロード.gdoc
# │       │   ├── xWORKS12月キャリア面談予約票20181225.gsheet
# │       │   ├── 参考ポートフォリオ.pdf
# │       │   ├── 転職希望者 履歴書
# │       │   │   ├── 190606_履歴書[#61050].pdf
# │       │   │   └── 鈴木優子
# │       │   │       ├── JISrirekisho平成31年6.pdf
# │       │   │       └── 職務経歴書平成31年6.pdf
# │       │   ├── マイナビ雛形）履歴書.gdoc
# │       │   ├── マイナビ雛形）職務経歴書.gdoc
# │       │   └── 面談一覧.gsheet
# │       └── エン・ジャパン高澤様：総会台本.gdoc
# └── sample_data
#     ├── anscombe.json
#     ├── california_housing_test.csv
#     ├── california_housing_train.csv
#     ├── mnist_test.csv
#     ├── mnist_train_small.csv
#     └── README.md
#
# 4950 directories, 48267 files
